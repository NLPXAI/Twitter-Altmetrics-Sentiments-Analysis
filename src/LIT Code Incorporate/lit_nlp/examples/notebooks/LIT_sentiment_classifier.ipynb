# %% [markdown]
# # Using the Language Interpretability Tool in Notebooks
#
# This notebook shows use of the [Language Interpretability Tool](https://pair-code.github.io/lit) on a binary classifier for labelling statement sentiment (0 for negative, 1 for positive).
#
# The LitWidget object constructor takes a dict mapping model names to model objects, and a dict mapping dataset names to dataset objects. Those will be the datasets and models displayed in LIT. It also optionally takes in a `height` parameter for how tall to render the LIT UI in pixels (it defaults to 1000 pixels). Running the constructor will cause the LIT server to be started in the background, loading the models and datasets and enabling the UI to be served.
#
# Render the LIT UI in an output cell by calling the `render` method on the LitWidget object. The LIT UI can be rendered multiple times in separate cells if desired. The widget also contains a `stop` method to shut down the LIT server.
#
# Copyright 2020 Google LLC.
# SPDX-License-Identifier: Apache-2.0

# %%
# Install LIT and transformers packages. The transformers package is needed by the model and dataset we are using.
# Replace tensorflow-datasets with the nightly package to get up-to-date dataset paths.
# !pip uninstall -y tensorflow-datasets
# !pip install lit_nlp tfds-nightly transformers==4.1.1

# !pip install tokenizers==0.9.4
# !pip install simpletransformers
# Out:
# Skipping tensorflow-datasets as it is not installed.
# Requirement already satisfied: lit_nlp in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (0.4.1)
# Requirement already satisfied: tfds-nightly in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (4.6.0.dev202207290046)
# Collecting transformers==4.1.1
#   Using cached https://files.pythonhosted.org/packages/50/0c/7d5950fcd80b029be0a8891727ba21e0cd27692c407c51261c3c921f6da3/transformers-4.1.1-py3-none-any.whl
# Requirement already satisfied: portpicker in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from lit_nlp) (1.5.2)
# Requirement already satisfied: Werkzeug in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from lit_nlp) (2.1.2)
# Requirement already satisfied: sacrebleu in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from lit_nlp) (2.2.0)
# Requirement already satisfied: ml-collections in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from lit_nlp) (0.1.1)
# Requirement already satisfied: scikit-learn in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from lit_nlp) (1.0.2)
# Requirement already satisfied: scipy in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from lit_nlp) (1.7.3)
# Requirement already satisfied: umap-learn in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from lit_nlp) (0.5.3)
# Requirement already satisfied: absl-py in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from lit_nlp) (1.0.0)
# Requirement already satisfied: pandas in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from lit_nlp) (1.3.5)
# Requirement already satisfied: attrs in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from lit_nlp) (21.4.0)
# Requirement already satisfied: numpy in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from lit_nlp) (1.21.5)
# Requirement already satisfied: promise in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tfds-nightly) (2.3)
# Requirement already satisfied: termcolor in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tfds-nightly) (1.1.0)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tfds-nightly) (5.8.0)
# Requirement already satisfied: tensorflow-metadata in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tfds-nightly) (1.9.0)
# Requirement already satisfied: etils[epath] in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tfds-nightly) (0.6.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tfds-nightly) (2.27.1)
# Requirement already satisfied: dill in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tfds-nightly) (0.3.5.1)
# Requirement already satisfied: tqdm in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tfds-nightly) (4.63.0)
# Requirement already satisfied: protobuf>=3.12.2 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tfds-nightly) (3.20.1)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tfds-nightly) (4.1.1)
# Requirement already satisfied: six in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from tfds-nightly) (1.16.0)
# Requirement already satisfied: toml in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tfds-nightly) (0.10.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from transformers==4.1.1) (2022.4.24)
# Requirement already satisfied: tokenizers==0.9.4 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from transformers==4.1.1) (0.9.4)
# Requirement already satisfied: sacremoses in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from transformers==4.1.1) (0.0.53)
# Requirement already satisfied: filelock in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from transformers==4.1.1) (3.7.0)
# Requirement already satisfied: packaging in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from transformers==4.1.1) (21.3)
# Requirement already satisfied: psutil in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from portpicker->lit_nlp) (5.9.0)
# Requirement already satisfied: portalocker in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from sacrebleu->lit_nlp) (2.5.1)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from sacrebleu->lit_nlp) (0.8.10)
# Requirement already satisfied: lxml in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from sacrebleu->lit_nlp) (4.9.1)
# Requirement already satisfied: colorama in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from sacrebleu->lit_nlp) (0.4.4)
# Requirement already satisfied: contextlib2 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from ml-collections->lit_nlp) (21.6.0)
# Requirement already satisfied: PyYAML in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from ml-collections->lit_nlp) (6.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn->lit_nlp) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn->lit_nlp) (3.1.0)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from umap-learn->lit_nlp) (0.5.7)
# Requirement already satisfied: numba>=0.49 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from umap-learn->lit_nlp) (0.55.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from pandas->lit_nlp) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from pandas->lit_nlp) (2.8.2)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from importlib-resources; python_version < "3.9"->tfds-nightly) (3.8.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tensorflow-metadata->tfds-nightly) (1.56.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from requests>=2.19.0->tfds-nightly) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from requests>=2.19.0->tfds-nightly) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from requests>=2.19.0->tfds-nightly) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from requests>=2.19.0->tfds-nightly) (2022.5.18)
# Requirement already satisfied: click in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from sacremoses->transformers==4.1.1) (8.1.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from packaging->transformers==4.1.1) (3.0.7)
# Requirement already satisfied: pywin32>=226; platform_system == "Windows" in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from portalocker->sacrebleu->lit_nlp) (303)
# Requirement already satisfied: llvmlite>=0.30 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from pynndescent>=0.5->umap-learn->lit_nlp) (0.38.0)
# Requirement already satisfied: setuptools in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from numba>=0.49->umap-learn->lit_nlp) (62.3.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from click->sacremoses->transformers==4.1.1) (4.11.3)
# Installing collected packages: transformers
#   Found existing installation: transformers 4.21.0
#     Uninstalling transformers-4.21.0:
#       Successfully uninstalled transformers-4.21.0
# Successfully installed transformers-4.1.1
# You are using pip version 19.0.3, however version 22.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: tokenizers==0.9.4 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (0.9.4)
# You are using pip version 19.0.3, however version 22.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Collecting simpletransformers
#   Using cached https://files.pythonhosted.org/packages/a5/cb/c0f19176b92f889ac00d9b408836e6c02005776633c5c90acbacbcb50c99/simpletransformers-0.63.7-py3-none-any.whl
# Requirement already satisfied: scipy in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from simpletransformers) (1.7.3)
# Collecting seqeval (from simpletransformers)
# Requirement already satisfied: tokenizers in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from simpletransformers) (0.9.4)
# Collecting wandb>=0.10.32 (from simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/70/f8/efeee68ada84717c7a5fb7001afd0b3697c9e3bc307284d0735938146d21/wandb-0.12.21-py2.py3-none-any.whl
# Requirement already satisfied: pandas in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from simpletransformers) (1.3.5)
# Requirement already satisfied: requests in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from simpletransformers) (2.27.1)
# Requirement already satisfied: tensorboard in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from simpletransformers) (2.9.0)
# Collecting sentencepiece (from simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/01/21/b78bb71b7fbab906eb1d10f67d1ba69761892016cf13c4f0c5dde123bb07/sentencepiece-0.1.96-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: tqdm>=4.47.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from simpletransformers) (4.63.0)
# Requirement already satisfied: numpy in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from simpletransformers) (1.21.5)
# Collecting streamlit (from simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/43/44/bed48d52eb32beed142022e26a4b81a4f54d9ae08b13bafdb2fcfa15ad32/streamlit-1.11.1-py2.py3-none-any.whl
# Requirement already satisfied: scikit-learn in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from simpletransformers) (1.0.2)
# Collecting datasets (from simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/13/68/8f123cf1b84fc32d749357b2c7ed6e9e61c06246965ba7f6f7a78cba54e9/datasets-2.4.0-py3-none-any.whl
# Requirement already satisfied: regex in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from simpletransformers) (2022.4.24)
# Collecting transformers>=4.6.0 (from simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/f5/74/b59516a72bd3208329c6af748fe67744ec9e67a2d33915edbb2a6b77db49/transformers-4.21.0-py3-none-any.whl
# Collecting setproctitle (from wandb>=0.10.32->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/5a/f1/c0f41e867430f3589cde462845ee4daa5cc9704f06d2bc516a3cd3b4be77/setproctitle-1.3.0-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: setuptools in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from wandb>=0.10.32->simpletransformers) (62.3.2)
# Collecting pathtools (from wandb>=0.10.32->simpletransformers)
# Collecting GitPython>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/83/32/ce68915670da6fd6b1e3fb4b3554b4462512f6441dddd194fc0f4f6ec653/GitPython-3.1.27-py3-none-any.whl
# Requirement already satisfied: Click!=8.0.0,>=7.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from wandb>=0.10.32->simpletransformers) (8.1.3)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from wandb>=0.10.32->simpletransformers) (5.9.0)
# Collecting sentry-sdk>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/34/ee/92a218cc1563eda06bc50117e1b5d004b46d1a7784c387c9bf91685e1311/sentry_sdk-1.9.0-py2.py3-none-any.whl
# Requirement already satisfied: PyYAML in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from wandb>=0.10.32->simpletransformers) (6.0)
# Collecting shortuuid>=0.5.0 (from wandb>=0.10.32->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/01/14/df1aa61e1bb75a6fff19b25d7d175b7f188dc15a70dfc80e7badd5bda1de/shortuuid-1.0.9-py3-none-any.whl
# Requirement already satisfied: protobuf<4.0dev,>=3.12.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from wandb>=0.10.32->simpletransformers) (3.20.1)
# Requirement already satisfied: six>=1.13.0 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from wandb>=0.10.32->simpletransformers) (1.16.0)
# Requirement already satisfied: promise<3,>=2.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from wandb>=0.10.32->simpletransformers) (2.3)
# Collecting docker-pycreds>=0.4.0 (from wandb>=0.10.32->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Requirement already satisfied: pytz>=2017.3 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from pandas->simpletransformers) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from pandas->simpletransformers) (2.8.2)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from requests->simpletransformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from requests->simpletransformers) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from requests->simpletransformers) (2022.5.18)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from requests->simpletransformers) (1.26.9)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tensorboard->simpletransformers) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tensorboard->simpletransformers) (1.46.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tensorboard->simpletransformers) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tensorboard->simpletransformers) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tensorboard->simpletransformers) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tensorboard->simpletransformers) (2.6.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tensorboard->simpletransformers) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tensorboard->simpletransformers) (0.37.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from tensorboard->simpletransformers) (2.1.2)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from tqdm>=4.47.0->simpletransformers) (0.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from streamlit->simpletransformers) (4.11.3)
# Collecting pympler>=0.9 (from streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/2c/42/41e1469ed0b37b9c8532cb8074bea179f7d85ee7e82a59b5b6c289ed6045/Pympler-1.0.1-py3-none-any.whl
# Collecting validators>=0.2 (from streamlit->simpletransformers)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from streamlit->simpletransformers) (9.0.1)
# Requirement already satisfied: toml in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from streamlit->simpletransformers) (0.10.2)
# Collecting pyarrow>=4.0 (from streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/d7/a3/46b059a7d8e382df1c704b04cab5c9f1b8c5dfeda76eb36d9a64b38d8097/pyarrow-8.0.0-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: attrs>=16.0.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from streamlit->simpletransformers) (21.4.0)
# Requirement already satisfied: tornado>=5.0 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from streamlit->simpletransformers) (6.1)
# Collecting tzlocal>=1.1 (from streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/31/b7/3bc2c1868f27677139b772e4fde95265b93151912fd90eb874827943bfcf/tzlocal-4.2-py3-none-any.whl
# Collecting watchdog; platform_system != "Darwin" (from streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/61/3f/a2fc9452b8161862a78674fda583d8e1addbbecf57a1e172b4a7a96e8087/watchdog-2.1.9-py3-none-win_amd64.whl
# Collecting altair>=3.2.0 (from streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/0a/fb/56aaac0c69d106e380ff868cd5bb6cccacf2b8917a8527532bc89804a52e/altair-4.2.0-py3-none-any.whl
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from streamlit->simpletransformers) (4.1.1)
# Collecting semver (from streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/0b/70/b84f9944a03964a88031ef6ac219b6c91e8ba2f373362329d8770ef36f02/semver-2.13.0-py2.py3-none-any.whl
# Requirement already satisfied: packaging>=14.1 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from streamlit->simpletransformers) (21.3)
# Collecting pydeck>=0.1.dev5 (from streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/7d/39/f58de74a3b4055bc7772bd77eccbf6e3a6e95d84fef53bb56ae93bea2fb9/pydeck-0.7.1-py2.py3-none-any.whl
# Collecting rich>=10.11.0 (from streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/f6/39/4cb526e0d505464376e3c47a812df6e6638363ebe66e6a63618831fe47ad/rich-12.5.1-py3-none-any.whl
# Requirement already satisfied: cachetools>=4.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from streamlit->simpletransformers) (5.1.0)
# Collecting blinker>=1.0.0 (from streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/30/41/caa5da2dbe6d26029dfe11d31dfa8132b4d6d30b6d6b61a24824075a5f06/blinker-1.5-py2.py3-none-any.whl
# Requirement already satisfied: joblib>=0.11 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn->simpletransformers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn->simpletransformers) (3.1.0)
# Collecting multiprocess (from datasets->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/4b/28/915e6d4943eab538963a4fac7c409aa4a75213f5e6b98d91334e9a284c5c/multiprocess-0.70.13-py37-none-any.whl
# Collecting aiohttp (from datasets->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/19/22/7a9ea2992cf7adf534eb51f7b6bfd4642bb15894ac36df4edb0838ee1fdb/aiohttp-3.8.1-cp37-cp37m-win_amd64.whl
# Collecting responses<0.19 (from datasets->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/79/f3/2b3a6dc5986303b3dd1bbbcf482022acb2583c428cd23f0b6d37b1a1a519/responses-0.18.0-py3-none-any.whl
# Collecting xxhash (from datasets->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/7a/95/4272e2b5668a5afbb1c5e9a82a19ad1d07876bf8221de28f5dd4c9af4888/xxhash-3.0.0-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: dill<0.3.6 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from datasets->simpletransformers) (0.3.5.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from datasets->simpletransformers) (0.6.0)
# Collecting fsspec[http]>=2021.11.1 (from datasets->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/58/fe/96674000d326e859ca2c654eeb9178f728e79ab466c2195bee305773d5a3/fsspec-2022.7.1-py3-none-any.whl
# Requirement already satisfied: filelock in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from transformers>=4.6.0->simpletransformers) (3.7.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/a3/7c/5d747655049bfbf75b5fcec57c8115896cb78d6fafa84f6d3ef4c0f13a98/gitdb-4.0.9-py3-none-any.whl
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->simpletransformers) (1.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.2.8)
# Requirement already satisfied: zipp>=0.5 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata>=1.4->streamlit->simpletransformers) (3.8.0)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from validators>=0.2->streamlit->simpletransformers) (5.1.1)
# Collecting pytz-deprecation-shim (from tzlocal>=1.1->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/eb/73/3eaab547ca809754e67e06871cff0fc962bafd4b604e15f31896a0f94431/pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl
# Collecting backports.zoneinfo; python_version < "3.9" (from tzlocal>=1.1->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/6c/99/513f2c4dd41522eefc42feb86854f6cf3b1add9c175c14d90c070775e484/backports.zoneinfo-0.2.1-cp37-cp37m-win_amd64.whl
# Collecting tzdata; platform_system == "Windows" (from tzlocal>=1.1->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/89/2d/49329ebec33b14dae61ecc8c85abe596341832fa36c4bcd3d99fddda018b/tzdata-2022.1-py2.py3-none-any.whl
# Collecting toolz (from altair>=3.2.0->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/7f/5c/922a3508f5bda2892be3df86c74f9cf1e01217c2b1f8a0ac4841d903e3e9/toolz-0.12.0-py3-none-any.whl
# Requirement already satisfied: entrypoints in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.4)
# Collecting jsonschema>=3.0 (from altair>=3.2.0->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/51/6b/0de110de6223c7fb45dc5a7c0ad19208bcc6017ca8b6adad9aa12066eb83/jsonschema-4.8.0-py3-none-any.whl
# Requirement already satisfied: jinja2 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from altair>=3.2.0->streamlit->simpletransformers) (3.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from packaging>=14.1->streamlit->simpletransformers) (3.0.7)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (5.1.1)
# Requirement already satisfied: ipykernel>=5.1.2; python_version >= "3.4" in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (6.9.2)
# Collecting ipywidgets>=7.0.0 (from pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/fa/b2/4af75a543f6c3475a982e814fecd9bf13ba06210c64a6da85475a39bd16b/ipywidgets-7.7.1-py2.py3-none-any.whl
# Collecting commonmark<0.10.0,>=0.9.0 (from rich>=10.11.0->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/b1/92/dfd892312d822f36c55366118b95d914e5f16de11044a27cf10a7d71bbbf/commonmark-0.9.1-py2.py3-none-any.whl
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from rich>=10.11.0->streamlit->simpletransformers) (2.11.2)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/c3/7c/1232ac7502f1fe7630b91a9a922641b46cb0c3994c64da5030289a0cbc51/frozenlist-1.3.0-cp37-cp37m-win_amd64.whl
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/3b/87/fe94898f2d44a93a35d5aa74671ed28094d80753a1113d68b799fab6dc22/aiosignal-1.2.0-py3-none-any.whl
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/79/f1/4679ba7965fa10fc5583d762fe1eabb68ba0e2344940f5c766c53ed09fcd/yarl-1.7.2-cp37-cp37m-win_amd64.whl
# Collecting asynctest==0.13.0; python_version < "3.8" (from aiohttp->datasets->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/e8/b6/8d17e169d577ca7678b11cd0d3ceebb0a6089a7f4a2de4b945fe4b1c86db/asynctest-0.13.0-py3-none-any.whl
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/d6/c1/8991e7c5385b897b8c020cdaad718c5b087a6626d1d11a23e1ea87e325a7/async_timeout-4.0.2-py3-none-any.whl
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/71/20/5388d06fab6600b61ff2cfc0ed87a7a8a09d25be9b269ff48d413e8ddb87/multidict-6.0.2-cp37-cp37m-win_amd64.whl
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/6d/01/7caa71608bc29952ae09b0be63a539e50d2484bc37747797a66a60679856/smmap-5.0.0-py3-none-any.whl
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->simpletransformers) (3.2.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.4.8)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 (from jsonschema>=3.0->altair>=3.2.0->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/3f/4f/721b1101d32569e255d6b11709196dbdd9e122a2aaea676d59d7b5f21971/pyrsistent-0.18.1-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->simpletransformers) (5.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages (from jinja2->altair>=3.2.0->streamlit->simpletransformers) (2.1.1)
# Requirement already satisfied: nest-asyncio in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.5.4)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit->simpletransformers) (7.32.0)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit->simpletransformers) (7.1.2)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.1.3)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.5.1)
# Collecting ipython-genutils~=0.2.0 (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl
# Collecting jupyterlab-widgets>=1.0.0; python_version >= "3.6" (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/a5/bb/210ce9e56cad3b9e7a0468582a3f22b06bb209430d6481031f05fafafad6/jupyterlab_widgets-1.1.1-py3-none-any.whl
# Collecting widgetsnbextension~=3.6.0 (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/9a/3d/a8ed056afe4e677943fd490263a6e45fbee2f025db738a1b4d17f75bb1ae/widgetsnbextension-3.6.1-py2.py3-none-any.whl
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit->simpletransformers) (3.0.28)
# Requirement already satisfied: jedi>=0.16 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.18.1)
# Requirement already satisfied: backcall in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.5)
# Requirement already satisfied: pyzmq>=13 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from jupyter-client<8.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit->simpletransformers) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from jupyter-client<8.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.9.2)
# Collecting notebook>=4.4.1 (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/b5/62/229659241aee54be38990e06e684bcfe5c9c8727185f5e39335be8821583/notebook-6.4.12-py3-none-any.whl
# Requirement already satisfied: wcwidth in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.8.3)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" and platform_python_implementation != "PyPy" in c:\users\asif raza\appdata\roaming\python\python37\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit->simpletransformers) (303)
# Collecting argon2-cffi (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/a8/07/946d5a9431bae05a776a59746ec385fbb79b526738d25e4202d3e0bbf7f4/argon2_cffi-21.3.0-py3-none-any.whl
# Collecting nbformat (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/2f/9a/97151abb954af0cc5d0e3ff2eb7b6d96704a317ac2c0ce0cc76cef003991/nbformat-5.4.0-py3-none-any.whl
# Collecting Send2Trash>=1.8.0 (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/47/26/3435896d757335ea53dce5abf8d658ca80757a7a06258451b358f10232be/Send2Trash-1.8.0-py3-none-any.whl
# Collecting prometheus-client (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/19/e5/7d4b4b3b0d8d2fdc55395cdb4271c6dbfde3c3ff7d6a6dbe63d19c4e2288/prometheus_client-0.14.1-py3-none-any.whl
# Collecting nbconvert>=5 (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/e8/f9/2de57146b8995d7f1b68d6fd0b4751d68c23f52e6f4ad926a7274184e8f2/nbconvert-6.5.0-py3-none-any.whl
# Collecting terminado>=0.8.3 (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/85/be/6b89563289bc8df86f4089efcc4e28d39feaaa4c0863ddcb32dee18d0957/terminado-0.15.0-py3-none-any.whl
# Collecting argon2-cffi-bindings (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/b9/e9/184b8ccce6683b0aa2fbb7ba5683ea4b9c5763f1356347f1312c32e3c66e/argon2-cffi-bindings-21.2.0.tar.gz
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting fastjsonschema (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/10/b9/953fc1e008d9f9b4a4220e7a43c543c904e45b63f7b9508a8ee7561ce582/fastjsonschema-2.16.1-py3-none-any.whl
# Collecting defusedxml (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/07/6c/aa3f2f849e01cb6a001cd8554a88d4c77c5c1a31c95bdf1cf9301e6d9ef4/defusedxml-0.7.1-py2.py3-none-any.whl
# Collecting tinycss2 (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/53/7b/5dba39bf0572f1f28e2844f08f74a73482a381de1d1feac3bbc6b808051e/tinycss2-1.1.1-py3-none-any.whl
# Collecting mistune<2,>=0.8.1 (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/09/ec/4b43dae793655b7d8a25f76119624350b4d65eb663459eb9603d7f1f0345/mistune-0.8.4-py2.py3-none-any.whl
# Collecting jupyterlab-pygments (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/c0/7e/c3d1df3ae9b41686e664051daedbd70eea2e1d2bd9d9c33e7e1455bc9f96/jupyterlab_pygments-0.2.2-py2.py3-none-any.whl
# Collecting bleach (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/d4/87/508104336a2bc0c4cfdbdceedc0f44dc72da3abc0460c57e323ddd1b3257/bleach-5.0.1-py3-none-any.whl
# Collecting pandocfilters>=1.4.1 (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/5e/a8/878258cffd53202a6cc1903c226cf09e58ae3df6b09f8ddfa98033286637/pandocfilters-1.5.0-py2.py3-none-any.whl
# Collecting beautifulsoup4 (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/9c/d8/909c4089dbe4ade9f9705f143c9f13f065049a9d5e7d34c828aefdd0a97c/beautifulsoup4-4.11.1-py3-none-any.whl
# Collecting nbclient>=0.5.0 (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/68/88/a3f13adcf5708cf0d5f9c4c95e12d1527f6498d87b30d463b588bb466c15/nbclient-0.6.6-py3-none-any.whl
# Collecting pywinpty>=1.1.0; os_name == "nt" (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/a8/43/d73c866d6b50ac86ec16c4e70465d4fe1f7aa405f59361cdc6970809444b/pywinpty-2.0.6-cp37-none-win_amd64.whl
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/32/2a/63cb8c07d151de92ff9d897b2eb27ba6a0e78dda8e4c5f70d7b8c16cd6a2/cffi-1.15.1-cp37-cp37m-win_amd64.whl
# Collecting webencodings>=0.4 (from tinycss2->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/16/e3/4ad79882b92617e3a4a0df1960d6bce08edfb637737ac5c3f3ba29022e25/soupsieve-2.3.2.post1-py3-none-any.whl
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers)
#   Using cached https://files.pythonhosted.org/packages/62/d5/5f610ebe421e85889f2e55e33b7f9a6795bd982198517d912eb1c76e1a53/pycparser-2.21-py2.py3-none-any.whl
# Building wheels for collected packages: argon2-cffi-bindings
#   Building wheel for argon2-cffi-bindings (PEP 517): started
#   Building wheel for argon2-cffi-bindings (PEP 517): finished with status 'error'
#   Complete output from command "c:\users\asif raza\appdata\local\programs\python\python37\python.exe" "c:\users\asif raza\appdata\local\programs\python\python37\lib\site-packages\pip\_vendor\pep517\_in_process.py" build_wheel C:\Users\ASIFRA~1\AppData\Local\Temp\tmpbqnvrnp3:
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-37
#   creating build\lib.win-amd64-cpython-37\_argon2_cffi_bindings
#   copying src\_argon2_cffi_bindings\_ffi_build.py -> build\lib.win-amd64-cpython-37\_argon2_cffi_bindings
#   copying src\_argon2_cffi_bindings\__init__.py -> build\lib.win-amd64-cpython-37\_argon2_cffi_bindings
#   running build_ext
#   generating cffi module 'build\\temp.win-amd64-cpython-37\\Release\\_ffi.c'
#   creating build\temp.win-amd64-cpython-37
#   creating build\temp.win-amd64-cpython-37\Release
#   building '_ffi' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#
#   ----------------------------------------
#   Running setup.py clean for argon2-cffi-bindings
# Failed to build argon2-cffi-bindings
#   Failed building wheel for argon2-cffi-bindings
# Could not build wheels for argon2-cffi-bindings which use PEP 517 and cannot be installed directly
# You are using pip version 19.0.3, however version 22.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# Fetch the trained model weights
# !wget https://storage.googleapis.com/what-if-tool-resources/lit-models/sst2_tiny.tar.gz
# !tar -xvf sst2_tiny.tar.gz
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# tar: Error opening archive: Failed to open 'sst2_tiny.tar.gz'

# %%
# Create the LIT widget with the model and dataset to analyze.
from lit_nlp import notebook
from lit_nlp.examples.datasets import glue
from lit_nlp.examples.models import glue_models

datasets = {'sst_dev': glue.SST2Data('validation')}
models = {'sst_tiny': glue_models.SST2Model('./')}

widget = notebook.LitWidget(models, datasets, height=800)
# Out:
# INFO:absl:Load dataset info from C:\Users\Asif Raza\tensorflow_datasets\glue\sst2\2.0.0
# INFO:absl:Reusing dataset glue (C:\Users\Asif Raza\tensorflow_datasets\glue\sst2\2.0.0)
# INFO:absl:Constructing tf.data.Dataset glue for split validation, from C:\Users\Asif Raza\tensorflow_datasets\glue\sst2\2.0.0
# file ./config.json not found
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\Asif Raza\AppData\Local\Programs\Python\Python37\lib\site-packages\transformers\configuration_utils.py in get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     405                 local_files_only=local_files_only,
# --> 406                 use_auth_token=use_auth_token,
#     407             )
#
# c:\Users\Asif Raza\AppData\Local\Programs\Python\Python37\lib\site-packages\transformers\file_utils.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#    1091         # File, but it doesn't exist.
# -> 1092         raise EnvironmentError("file {} not found".format(url_or_filename))
#    1093     else:
#
# OSError: file ./config.json not found
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16612\2241927273.py in <module>
#       5
#       6 datasets = {'sst_dev': glue.SST2Data('validation')}
# ----> 7 models = {'sst_tiny': glue_models.SST2Model('./')}
#       8
#       9 widget = notebook.LitWidget(models, datasets, height=800)
#
# c:\Users\Asif Raza\AppData\Local\Programs\Python\Python37\lib\site-packages\lit_nlp\examples\models\glue_models.py in __init__(self, *args, **kw)
#     504         labels=["0", "1"],
#     505         null_label_idx=0,
# --> 506         **kw)
#     507
#     508
#
# c:\Users\Asif Raza\AppData\Local\Programs\Python\Python37\lib\site-packages\lit_nlp\examples\models\glue_models.py in __init__(self, model_name_or_path, **config_kw)
#      59                **config_kw):
#      60     self.config = GlueModelConfig(**config_kw)
# ---> 61     self._load_model(model_name_or_path)
#      62     self._lock = threading.Lock()
#      63
#
# c:\Users\Asif Raza\AppData\Local\Programs\Python\Python37\lib\site-packages\lit_nlp\examples\models\glue_models.py in _load_model(self, model_name_or_path)
#      65     """Load model. Can be overridden for testing."""
#      66     self.tokenizer = transformers.AutoTokenizer.from_pretrained(
# ---> 67         model_name_or_path)
#      68     self.vocab = self.tokenizer.convert_ids_to_tokens(
#      69         range(len(self.tokenizer)))
#
# c:\Users\Asif Raza\AppData\Local\Programs\Python\Python37\lib\site-packages\transformers\models\auto\tokenization_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     343         config = kwargs.pop("config", None)
#     344         if not isinstance(config, PretrainedConfig):
# --> 345             config = AutoConfig.from_pretrained(pretrained_model_name_or_path, **kwargs)
#     346
#     347         use_fast = kwargs.pop("use_fast", True)
#
# c:\Users\Asif Raza\AppData\Local\Programs\Python\Python37\lib\site-packages\transformers\models\auto\configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     347             {'foo': False}
#     348         """
# --> 349         config_dict, _ = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     350
#     351         if "model_type" in config_dict:
#
# c:\Users\Asif Raza\AppData\Local\Programs\Python\Python37\lib\site-packages\transformers\configuration_utils.py in get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     416                 f"- or '{pretrained_model_name_or_path}' is the correct path to a directory containing a {CONFIG_NAME} file\n\n"
#     417             )
# --> 418             raise EnvironmentError(msg)
#     419
#     420         except json.JSONDecodeError:
#
# OSError: Can't load config for './'. Make sure that:
#
# - './' is a correct model identifier listed on 'https://huggingface.co/models'
#
# - or './' is the correct path to a directory containing a config.json file

# %%
# Render the widget
widget.render()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16612\1880205372.py in <module>
#       1 # Render the widget
# ----> 2 widget.render()
#
# NameError: name 'widget' is not defined
